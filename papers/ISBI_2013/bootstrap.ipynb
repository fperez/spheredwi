# %% [markdown]
# ## Set up an online notebook
#
# - Step 1: Launch IPython on a micro instance on Amazon EC2:
#   https://notebookcloud.appspot.com
# - Download this notebook to your local computer from https://github.com/fperez/spheredwi/tree/master/papers/ISBI_2013
# - Upload this file to the IPython notebook console

# %%
from IPython.display import Image
Image(filename='figs/dashboard-arrow.png', width="500")
# Out:
# <img src="...

# %% [markdown]
# ## Setting up the environment
#
# Execute the following cells in this notebook to configure the Amazon image for DiPy and 3-D plotting support.

# %%
# !sudo apt-get install -y git mayavi2 python-nibabel xvfb
# !git clone https://github.com/fperez/spheredwi.git
# !git clone https://github.com/nipy/dipy.git
# !cd dipy && python setup.py build_ext -i
